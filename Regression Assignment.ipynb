# %%
import graphlab as gl

# %%
gl.canvas.set_target('ipynb')

# %%
sales = gl.SFrame('home_data.gl/')
# Out:
# [INFO] 1451083855 : INFO:     (initialize_globals_from_environment:282): Setting configuration variable GRAPHLAB_FILEIO_ALTERNATIVE_SSL_CERT_FILE to C:\Users\rax\AppData\Local\Dato\Dato Launcher\lib\site-packages\certifi\cacert.pem
# 1451083855 : INFO:     (initialize_globals_from_environment:282): Setting configuration variable GRAPHLAB_FILEIO_ALTERNATIVE_SSL_CERT_DIR to
# This non-commercial license of GraphLab Create is assigned to rave1@umbc.edu and will expire on December 23, 2016. For commercial licensing options, visit https://dato.com/buy/.
#
# [INFO] Start server at: ipc:///tmp/graphlab_server-2440 - Server binary: C:\Users\rax\AppData\Local\Dato\Dato Launcher\lib\site-packages\graphlab\unity_server.exe - Server log: C:\Users\rax\AppData\Local\Temp\graphlab_server_1451083855.log.0
# [INFO] GraphLab Server Version: 1.7.1

# %%
sales
# Out:
# Columns:
# 	id	str
# 	date	datetime
# 	price	int
# 	bedrooms	str
# 	bathrooms	str
# 	sqft_living	int
# 	sqft_lot	int
# 	floors	str
# 	waterfront	int
# 	view	int
# 	condition	int
# 	grade	int
# 	sqft_above	int
# 	sqft_basement	int
# 	yr_built	int
# 	yr_renovated	int
# 	zipcode	str
# 	lat	float
# 	long	float
# 	sqft_living15	float
# 	sqft_lot15	float
#
# Rows: 21613
#
# Data:
# +------------+---------------------------+---------+----------+-----------+-------------+
# |     id     |            date           |  price  | bedrooms | bathrooms | sqft_living |
# +------------+---------------------------+---------+----------+-----------+-------------+
# | 7129300520 | 2014-10-13 00:00:00+00:00 |  221900 |    3     |     1     |     1180    |
# | 6414100192 | 2014-12-09 00:00:00+00:00 |  538000 |    3     |    2.25   |     2570    |
# | 5631500400 | 2015-02-25 00:00:00+00:00 |  180000 |    2     |     1     |     770     |
# ...

# %%
sales[zipcode == '98039']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-3c58af3479d3> in <module>()
# ----> 1 sales[zipcode == '98039']
#
# NameError: name 'zipcode' is not defined

# %%
sales.show(view='Scatter Plot', x='zipcode', y='price')

# %%
average = sales.groupby(key_columns='zipcode', operations={'price':gl.aggregate.AVG('price')})

# %%
average.print_rows(num_rows=70)
# Out:
# +---------+---------------+
# | zipcode |     price     |
# +---------+---------------+
# |  98032  |   251296.24   |
# |  98115  |  619900.5506  |
# |  98075  | 790576.668524 |
# |  98034  | 521652.858716 |
# |  98106  |  319581.39403 |
# |  98024  | 580526.790123 |
# |  98122  | 634360.175862 |
# |  98010  |   423665.99   |
# |  98117  | 576795.007233 |
# |  98116  | 618634.178788 |
# |  98001  | 280804.690608 |
# |  98178  | 310612.755725 |
# |  98011  | 490351.466667 |
# |  98056  | 420890.549261 |
# |  98074  |  685605.77551 |
# |  98022  | 315709.303419 |
# |  98065  | 527961.203226 |
# |  98144  | 594547.641399 |
# |  98136  | 551688.673004 |
# |  98052  | 645231.452962 |
# |  98023  | 286732.791583 |
# |  98004  | 1355927.09779 |
# |  98028  | 462480.035336 |
# |  98008  | 645507.378092 |
# |  98188  | 289078.345588 |
# |  98040  | 1194230.00355 |
# |  98031  | 300539.890511 |
# |  98107  | 579053.417293 |
# |  98125  | 469455.770732 |
# |  98155  | 423725.695067 |
# ...

# %% [markdown]
# ## 2160606.6

# %%
print len(sales[sales['zipcode'] == 98039])
# Out:
# 0

# %%
sales[sales['zipcode'] == '98039']
# Out:
# Columns:
# 	id	str
# 	date	datetime
# 	price	int
# 	bedrooms	str
# 	bathrooms	str
# 	sqft_living	int
# 	sqft_lot	int
# 	floors	str
# 	waterfront	int
# 	view	int
# 	condition	int
# 	grade	int
# 	sqft_above	int
# 	sqft_basement	int
# 	yr_built	int
# 	yr_renovated	int
# 	zipcode	str
# 	lat	float
# 	long	float
# 	sqft_living15	float
# 	sqft_lot15	float
#
# Rows: Unknown
#
# Data:
# +------------+---------------------------+---------+----------+-----------+-------------+
# |     id     |            date           |  price  | bedrooms | bathrooms | sqft_living |
# +------------+---------------------------+---------+----------+-----------+-------------+
# | 3625049014 | 2014-08-29 00:00:00+00:00 | 2950000 |    4     |    3.5    |     4860    |
# | 2540700110 | 2015-02-12 00:00:00+00:00 | 1905000 |    4     |    3.5    |     4210    |
# | 3262300940 | 2014-11-07 00:00:00+00:00 |  875000 |    3     |     1     |     1220    |
# ...

# %%
sales
# Out:
# Columns:
# 	id	str
# 	date	datetime
# 	price	int
# 	bedrooms	str
# 	bathrooms	str
# 	sqft_living	int
# 	sqft_lot	int
# 	floors	str
# 	waterfront	int
# 	view	int
# 	condition	int
# 	grade	int
# 	sqft_above	int
# 	sqft_basement	int
# 	yr_built	int
# 	yr_renovated	int
# 	zipcode	str
# 	lat	float
# 	long	float
# 	sqft_living15	float
# 	sqft_lot15	float
#
# Rows: 21613
#
# Data:
# +------------+---------------------------+---------+----------+-----------+-------------+
# |     id     |            date           |  price  | bedrooms | bathrooms | sqft_living |
# +------------+---------------------------+---------+----------+-----------+-------------+
# | 7129300520 | 2014-10-13 00:00:00+00:00 |  221900 |    3     |     1     |     1180    |
# | 6414100192 | 2014-12-09 00:00:00+00:00 |  538000 |    3     |    2.25   |     2570    |
# | 5631500400 | 2015-02-25 00:00:00+00:00 |  180000 |    2     |     1     |     770     |
# ...

# %%
print len(sales[(sales['sqft_living'] >= 2000) & (sales['sqft_living'] <= 4000)])
# Out:
# 9221

# %%
print len(sales)
# Out:
# 21613

# %%
print (len(sales[(sales['sqft_living'] >= 2000) & (sales['sqft_living'] <= 4000)]) / len(sales))
# Out:
# 0

# %%
(float(9221) / 21613) * 100
# Out:
# 42.66413732475825

# %% [markdown]
# ## 42.66413732475825

# %%
advanced_features = [
'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors', 'zipcode',
'condition', # condition of house
'grade', # measure of quality of construction				
'waterfront', # waterfront property				
'view', # type of view				
'sqft_above', # square feet above ground				
'sqft_basement', # square feet in basement				
'yr_built', # the year built				
'yr_renovated', # the year renovated				
'lat', 'long', # the lat-long of the parcel				
'sqft_living15', # average sq.ft. of 15 nearest neighbors 				
'sqft_lot15', # average lot size of 15 nearest neighbors 
]

# %%
advanced_features
# Out:
# ['bedrooms',
#  'bathrooms',
#  'sqft_living',
#  'sqft_lot',
#  'floors',
#  'zipcode',
#  'condition',
#  'grade',
#  'waterfront',
#  'view',
#  'sqft_above',
#  'sqft_basement',
#  'yr_built',
#  'yr_renovated',
#  'lat',
#  'long',
#  'sqft_living15',
#  'sqft_lot15']

# %%
train_data, test_data = sales.random_split(.8, seed=0)

# %%
advanced_model = gl.linear_regression.create(train_data, target='price', features=advanced_features, validation_set=None)
# Out:
# PROGRESS: Linear regression:
# PROGRESS: --------------------------------------------------------
# PROGRESS: Number of examples          : 17384
# PROGRESS: Number of features          : 18
# PROGRESS: Number of unpacked features : 18
# PROGRESS: Number of coefficients    : 127
# PROGRESS: Starting Newton Method
# PROGRESS: --------------------------------------------------------
# PROGRESS: +-----------+----------+--------------+--------------------+---------------+
# PROGRESS: | Iteration | Passes   | Elapsed Time | Training-max_error | Training-rmse |
# PROGRESS: +-----------+----------+--------------+--------------------+---------------+
# PROGRESS: | 1         | 2        | 1.106440     | 3469012.450663     | 154580.940735 |
# PROGRESS: +-----------+----------+--------------+--------------------+---------------+
# PROGRESS: SUCCESS: Optimal solution found.
# PROGRESS:

# %%
am = advanced_model.evaluate(test_data)['rmse']

# %% [markdown]
# ## 'rmse': 156831.11680191013

# %%
my_features = ['sqft_living', 'bedrooms', 'bathrooms', 'sqft_lot', 'floors', 'zipcode']

# %%
my_features_model = gl.linear_regression.create(train_data, target='price', features=my_features, validation_set=None )
# Out:
# PROGRESS: Linear regression:
# PROGRESS: --------------------------------------------------------
# PROGRESS: Number of examples          : 17384
# PROGRESS: Number of features          : 6
# PROGRESS: Number of unpacked features : 6
# PROGRESS: Number of coefficients    : 115
# PROGRESS: Starting Newton Method
# PROGRESS: --------------------------------------------------------
# PROGRESS: +-----------+----------+--------------+--------------------+---------------+
# PROGRESS: | Iteration | Passes   | Elapsed Time | Training-max_error | Training-rmse |
# PROGRESS: +-----------+----------+--------------+--------------------+---------------+
# PROGRESS: | 1         | 2        | 0.036241     | 3763208.270524     | 181908.848367 |
# PROGRESS: +-----------+----------+--------------+--------------------+---------------+
# PROGRESS: SUCCESS: Optimal solution found.
# PROGRESS:

# %%
y = my_features_model.evaluate(test_data)['rmse']

# %%
179542-156831
# Out:
# 22711

# %%
dict = {'a': 8, 'text':'dictionary'}

# %%
x=dict['text']

# %%
x
# Out:
# 'dictionary'

# %%
y-am
# Out:
# 22711.31651078089

# %%
sales[sales['zipcode'] == '98039']
# Out:
# Columns:
# 	id	str
# 	date	datetime
# 	price	int
# 	bedrooms	str
# 	bathrooms	str
# 	sqft_living	int
# 	sqft_lot	int
# 	floors	str
# 	waterfront	int
# 	view	int
# 	condition	int
# 	grade	int
# 	sqft_above	int
# 	sqft_basement	int
# 	yr_built	int
# 	yr_renovated	int
# 	zipcode	str
# 	lat	float
# 	long	float
# 	sqft_living15	float
# 	sqft_lot15	float
#
# Rows: Unknown
#
# Data:
# +------------+---------------------------+---------+----------+-----------+-------------+
# |     id     |            date           |  price  | bedrooms | bathrooms | sqft_living |
# +------------+---------------------------+---------+----------+-----------+-------------+
# | 3625049014 | 2014-08-29 00:00:00+00:00 | 2950000 |    4     |    3.5    |     4860    |
# | 2540700110 | 2015-02-12 00:00:00+00:00 | 1905000 |    4     |    3.5    |     4210    |
# | 3262300940 | 2014-11-07 00:00:00+00:00 |  875000 |    3     |     1     |     1220    |
# ...

# %%
(sales[sales['zipcode'] == '98039'])['price'].mean()
# Out:
# 2160606.5999999996
