# %%
i = 5

i

print i
# Out:
# 5

# %%
i =1
i
# Out:
# 1

# %% [markdown]
# Advanced

# %% [markdown]
# Dictionary

# %% [markdown]
# ## Advanced Python

# %% [markdown]
# ## Graphlab create

# %%
import graphlab

# %%
sf = graphlab.SFrame('FL_insurance_sample.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e9c20a5e9a3c> in <module>()
# ----> 1 sf = graphlab.SFrame('FL_insurance_sample.csv')
#
# NameError: name 'graphlab' is not defined

# %%
import graphlab
sf = graphlab.SFrame('FL_insurance_sample.csv')
# Out:
# [INFO] 1450934438 : INFO:     (initialize_globals_from_environment:282): Setting configuration variable GRAPHLAB_FILEIO_ALTERNATIVE_SSL_CERT_FILE to C:\Users\rax\AppData\Local\Dato\Dato Launcher\lib\site-packages\certifi\cacert.pem
# 1450934438 : INFO:     (initialize_globals_from_environment:282): Setting configuration variable GRAPHLAB_FILEIO_ALTERNATIVE_SSL_CERT_DIR to
# This non-commercial license of GraphLab Create is assigned to rave1@umbc.edu and will expire on December 23, 2016. For commercial licensing options, visit https://dato.com/buy/.
#
# [INFO] Start server at: ipc:///tmp/graphlab_server-880 - Server binary: C:\Users\rax\AppData\Local\Dato\Dato Launcher\lib\site-packages\graphlab\unity_server.exe - Server log: C:\Users\rax\AppData\Local\Temp\graphlab_server_1450934438.log.0
# [INFO] GraphLab Server Version: 1.7.1
# PROGRESS: Finished parsing file C:\Users\rax\iPython Workspace\FL_insurance_sample.csv
# PROGRESS: Parsing completed. Parsed 100 lines in 0.176682 secs.
# ...

# %%
sf.head()
# Out:
# Columns:
# 	policyID	int
# 	statecode	str
# 	county	str
# 	eq_site_limit	float
# 	hu_site_limit	float
# 	fl_site_limit	float
# 	fr_site_limit	float
# 	tiv_2011	float
# 	tiv_2012	float
# 	eq_site_deductible	int
# 	hu_site_deductible	float
# 	fl_site_deductible	int
# 	fr_site_deductible	int
# 	point_latitude	float
# 	point_longitude	float
# 	line	str
# 	construction	str
# 	point_granularity	int
#
# Rows: 10
#
# Data:
# +----------+-----------+-------------+---------------+---------------+---------------+
# | policyID | statecode |    county   | eq_site_limit | hu_site_limit | fl_site_limit |
# +----------+-----------+-------------+---------------+---------------+---------------+
# |  119736  |     FL    | CLAY COUNTY |    498960.0   |    498960.0   |    498960.0   |
# |  448094  |     FL    | CLAY COUNTY |   1322376.3   |   1322376.3   |   1322376.3   |
# |  206893  |     FL    | CLAY COUNTY |    190724.4   |    190724.4   |    190724.4   |
# ...

# %%
sf
# Out:
# Columns:
# 	policyID	int
# 	statecode	str
# 	county	str
# 	eq_site_limit	float
# 	hu_site_limit	float
# 	fl_site_limit	float
# 	fr_site_limit	float
# 	tiv_2011	float
# 	tiv_2012	float
# 	eq_site_deductible	int
# 	hu_site_deductible	float
# 	fl_site_deductible	int
# 	fr_site_deductible	int
# 	point_latitude	float
# 	point_longitude	float
# 	line	str
# 	construction	str
# 	point_granularity	int
#
# Rows: 36634
#
# Data:
# +----------+-----------+-------------+---------------+---------------+---------------+
# | policyID | statecode |    county   | eq_site_limit | hu_site_limit | fl_site_limit |
# +----------+-----------+-------------+---------------+---------------+---------------+
# |  119736  |     FL    | CLAY COUNTY |    498960.0   |    498960.0   |    498960.0   |
# |  448094  |     FL    | CLAY COUNTY |   1322376.3   |   1322376.3   |   1322376.3   |
# |  206893  |     FL    | CLAY COUNTY |    190724.4   |    190724.4   |    190724.4   |
# ...

# %%
sf.tail()
# Out:
# Columns:
# 	policyID	int
# 	statecode	str
# 	county	str
# 	eq_site_limit	float
# 	hu_site_limit	float
# 	fl_site_limit	float
# 	fr_site_limit	float
# 	tiv_2011	float
# 	tiv_2012	float
# 	eq_site_deductible	int
# 	hu_site_deductible	float
# 	fl_site_deductible	int
# 	fr_site_deductible	int
# 	point_latitude	float
# 	point_longitude	float
# 	line	str
# 	construction	str
# 	point_granularity	int
#
# Rows: 10
#
# Data:
# +----------+-----------+-----------------+---------------+---------------+
# | policyID | statecode |      county     | eq_site_limit | hu_site_limit |
# +----------+-----------+-----------------+---------------+---------------+
# |  827844  |     FL    | PINELLAS COUNTY |      0.0      |    38112.3    |
# |  876385  |     FL    | PINELLAS COUNTY |      0.0      |    18312.3    |
# |  167630  |     FL    | PINELLAS COUNTY |      0.0      |     4522.5    |
# |  241496  |     FL    | PINELLAS COUNTY |      0.0      |     1350.0    |
# ...

# %%
sf.show()
# Out:
# Canvas is accessible via web browser at the URL: http://localhost:51959/index.html
# Opening Canvas in default web browser.

# %%
sf = graphlab.SFrame('FL_insurance_sample.csv')
# Out:
# PROGRESS: Finished parsing file C:\Users\rax\iPython Workspace\FL_insurance_sample.csv
# PROGRESS: Parsing completed. Parsed 100 lines in 0.02214 secs.
# ------------------------------------------------------
# Inferred types from first line of file as
# column_type_hints=[long,str,str,float,float,float,float,float,float,long,float,long,long,float,float,str,str,long]
# If parsing fails due to incorrect types, you can correct
# the inferred type list above and pass it to read_csv in
# the column_type_hints argument
# ------------------------------------------------------
# PROGRESS: Finished parsing file C:\Users\rax\iPython Workspace\FL_insurance_sample.csv
# PROGRESS: Parsing completed. Parsed 389 lines in 0.023015 secs.

# %%
sf
# Out:
# Columns:
# 	policyID	int
# 	statecode	str
# 	county	str
# 	eq_site_limit	float
# 	hu_site_limit	float
# 	fl_site_limit	float
# 	fr_site_limit	float
# 	tiv_2011	float
# 	tiv_2012	float
# 	eq_site_deductible	int
# 	hu_site_deductible	float
# 	fl_site_deductible	int
# 	fr_site_deductible	int
# 	point_latitude	float
# 	point_longitude	float
# 	line	str
# 	construction	str
# 	point_granularity	int
#
# Rows: 389
#
# Data:
# +----------+-----------+-------------+---------------+---------------+---------------+
# | policyID | statecode |    county   | eq_site_limit | hu_site_limit | fl_site_limit |
# +----------+-----------+-------------+---------------+---------------+---------------+
# |  119736  |     FL    | CLAY COUNTY |    498960.0   |    498960.0   |    498960.0   |
# |  448094  |     FL    | CLAY COUNTY |   1322376.3   |   1322376.3   |   1322376.3   |
# |  206893  |     FL    | CLAY COUNTY |    190724.4   |    190724.4   |    190724.4   |
# ...

# %%
sf.show()
# Out:
# Canvas is accessible via web browser at the URL: http://localhost:51959/index.html
# Opening Canvas in default web browser.

# %%
sf.tail()
# Out:
# Columns:
# 	policyID	int
# 	statecode	str
# 	county	str
# 	eq_site_limit	float
# 	hu_site_limit	float
# 	fl_site_limit	float
# 	fr_site_limit	float
# 	tiv_2011	float
# 	tiv_2012	float
# 	eq_site_deductible	int
# 	hu_site_deductible	float
# 	fl_site_deductible	int
# 	fr_site_deductible	int
# 	point_latitude	float
# 	point_longitude	float
# 	line	str
# 	construction	str
# 	point_granularity	int
#
# Rows: 10
#
# Data:
# +----------+-----------+-----------------+---------------+---------------+---------------+
# | policyID | statecode |      county     | eq_site_limit | hu_site_limit | fl_site_limit |
# +----------+-----------+-----------------+---------------+---------------+---------------+
# |  732449  |     FL    | HAMILTON COUNTY |      0.0      |    15873.72   |      0.0      |
# |  665653  |     FL    | HAMILTON COUNTY |      0.0      |   246924.56   |      0.0      |
# |  939634  |     FL    | HAMILTON COUNTY |      0.0      |   942304.98   |      0.0      |
# ...

# %%
sf.show()
# Out:
# Canvas is accessible via web browser at the URL: http://localhost:51959/index.html
# Opening Canvas in default web browser.

# %%
graphlab.canvas.set_target('ipynb')

# %%
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-13-ffb714f771f6> in <module>()
# ----> 1 sf['County']
#
# C:\Users\rax\AppData\Local\Dato\Dato Launcher\lib\site-packages\graphlab\data_structures\sframe.pyc in __getitem__(self, key)
#    3554             return self._row_selector(key)
#    3555         elif type(key) is str:
# -> 3556             return self.select_column(key)
#    3557         elif type(key) is type:
#    3558             return self.select_columns([key])
#
# C:\Users\rax\AppData\Local\Dato\Dato Launcher\lib\site-packages\graphlab\data_structures\sframe.pyc in select_column(self, key)
#    3159             raise TypeError("Invalid key type: must be str")
#    3160         with cython_context():
# -> 3161             return SArray(data=[], _proxy=self.__proxy__.select_column(key))
#    3162
#    3163     def select_columns(self, keylist):
#
# ...

# %%
sf['county'].show()

# %%
sf['County'].show(view='Categorical')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-15-a99f8eb5ecfd> in <module>()
# ----> 1 sf['County'].show(view='Categorical')
#
# C:\Users\rax\AppData\Local\Dato\Dato Launcher\lib\site-packages\graphlab\data_structures\sframe.pyc in __getitem__(self, key)
#    3554             return self._row_selector(key)
#    3555         elif type(key) is str:
# -> 3556             return self.select_column(key)
#    3557         elif type(key) is type:
#    3558             return self.select_columns([key])
#
# C:\Users\rax\AppData\Local\Dato\Dato Launcher\lib\site-packages\graphlab\data_structures\sframe.pyc in select_column(self, key)
#    3159             raise TypeError("Invalid key type: must be str")
#    3160         with cython_context():
# -> 3161             return SArray(data=[], _proxy=self.__proxy__.select_column(key))
#    3162
# ...

# %%
sf['county'].show()

# %%
sf['county'].show(view='Categorical')

# %% [markdown]
# ## Inspect Columns of dataset

# %%
sf['county']
# Out:
# dtype: str
# Rows: 389
# ...

# %%
sf['hu_site_limit'].head()
# Out:
# dtype: float
# Rows: 10
# [498960.0, 1322376.3, 190724.4, 79520.76, 254281.5, 515035.62, 19260000.0, 328500.0, 315000.0, 705600.0]

# %%
sf['hu_site_limit'].mean()
# Out:
# 529120.145681234

# %%
sf['hu_site_limit'].max()
# Out:
# 19260000.0

# %%
sf['address'] = sf['county'] + ' ' + sf['statecode']

# %%
sf.head()
# Out:
# Columns:
# 	policyID	int
# 	statecode	str
# 	county	str
# 	eq_site_limit	float
# 	hu_site_limit	float
# 	fl_site_limit	float
# 	fr_site_limit	float
# 	tiv_2011	float
# 	tiv_2012	float
# 	eq_site_deductible	int
# 	hu_site_deductible	float
# 	fl_site_deductible	int
# 	fr_site_deductible	int
# 	point_latitude	float
# 	point_longitude	float
# 	line	str
# 	construction	str
# 	point_granularity	int
# 	address	str
#
# Rows: 10
#
# Data:
# +----------+-----------+-------------+---------------+---------------+---------------+
# | policyID | statecode |    county   | eq_site_limit | hu_site_limit | fl_site_limit |
# +----------+-----------+-------------+---------------+---------------+---------------+
# |  119736  |     FL    | CLAY COUNTY |    498960.0   |    498960.0   |    498960.0   |
# |  448094  |     FL    | CLAY COUNTY |   1322376.3   |   1322376.3   |   1322376.3   |
# |  206893  |     FL    | CLAY COUNTY |    190724.4   |    190724.4   |    190724.4   |
# ...

# %% [markdown]
# ## Advanced SFrame functions
